# %% [markdown]
# # JMN Shadow Reproduction in Google Colab
#
# This notebook clones the GitHub repository, installs the required Python packages, generates the supported figures, and displays them.
#
# Supported figures:
# - Figure 2(a): Schwarzschild intensity profile
# - Figure 2(b): Schwarzschild shadow image
# - Figure 2(c): JMN1 intensity profile
# - Figure 2(d): JMN1 shadow image

# %%
# !git clone https://github.com/jayvermatrivedi/JMN-shadow.git
# %cd JMN-shadow
# !pip install -r requirements.txt

# %%
# !python examples/run_all_figures.py

# %%
from IPython.display import Image, display

display(Image(filename='figures/figure2a_schwarzschild_profile.png'))
display(Image(filename='figures/figure2b_schwarzschild_shadow.png'))
display(Image(filename='figures/figure2c_jmn1_profile.png'))
display(Image(filename='figures/figure2d_jmn1_shadow.png'))

# %% [markdown]
# ## If you want to run only one figure
#
# Use one of these commands:
#
# ```python
# !python examples/reproduce_figure2a.py
# !python examples/reproduce_figure2b.py
# !python examples/reproduce_figure2c.py
# !python examples/reproduce_figure2d.py
# ```
